# %% [markdown]
# # 안녕하세요^^
# # 미니 프로젝트에 오신 여러분을 환영합니다.
#
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.

# %% [markdown]
# ## 기본 데이터
#
# [기본 데이터]
# * 서울시 특정구 특정동의 생활인구 데이터입니다.
# * data2017.csv
# * data2018.csv
# * data2019.csv
# * data2020.csv
# * data2021.csv
# * data2022.csv
#
#
# * 2017~2021년은 데이터 전부(train data), 2022년은 1~6월(test data)까지 제공합니다.
#
# [변수 소개]
# * index : 날짜
#
# * 시간대 : 0 ~ 23
#
# * 총 생활 인구 수 : 생활 인구 합계
#
# * 각 성별, 연령대 별 생활 인구수

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'data2017.csv'파일을 'df2017' 변수에 저장하고 그 Shape을 확인하세요.
# * 아래에 'Pandas'를 Import하고 'data2017.csv'파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
import numpy as np
import pandas as pd

# %%
df17 = pd.read_csv('../data/test2017.csv', sep=',', index_col=0)

# %%
df17.shape
# Out:
# (8760, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 2. 추가 데이터 불러오기

# %% [markdown]
# #### [실습문제2] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2018.csv' ~ 'data2021.csv'를 df18 ~ df21로 각각 불러오고, 이미 불러와 있던 df17을 포함하여 'df_total'로 합쳐보세요. 그리고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
df18 = pd.read_csv('../data/test2018.csv', sep=',', index_col=0)
df19 = pd.read_csv('../data/test2019.csv', sep=',', index_col=0)
df20 = pd.read_csv('../data/test2020.csv', sep=',', index_col=0)
df21 = pd.read_csv('../data/test2021.csv', sep=',', index_col=0)

# %%
df_train = pd.concat([df17,df18,df19,df20,df21])

# %%
df_train.shape
# Out:
# (43512, 31)

# %% [markdown]
# #### [실습문제4] 데이터 확인
# * df_total와 df_test 데이터를 head, tail. describe, info 등을 활용하여 확인하세요.

# %%
df_train.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  43922.2281       953.7652         627.7225
# 1  20170101      1  43763.4929       962.2909         633.3292
# 2  20170101      2  43561.5708       932.2939         613.6027
# 3  20170101      3  43928.9929       926.3617         609.7009
# 4  20170101      4  44150.2973       922.8893         607.4184
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         927.6134        2025.0630        2278.7336        1744.8161
# 1         970.6215        2045.7002        2412.6287        1765.7725
# 2         964.3505        2057.3601        2419.0941        1734.0569
# 3         983.2400        2100.5071        2480.1898        1780.3833
# 4         990.0534        2128.2729        2531.6549        1774.7853
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1713.6754  ...        2060.1511        1734.3805        1713.3332
# 1        1765.1171  ...        2037.5677        1745.5960        1735.4797
# 2        1746.3940  ...        2005.4838        1750.7594        1710.6116
# 3        1723.6640  ...        2044.6913        1777.4169        1718.1475
# 4        1752.0073  ...        2060.8824        1801.2144        1718.2957
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1754.6515        1636.4175        1521.3668        1728.0639
# 1        1700.9196        1619.3672        1474.8418        1661.3750
# 2        1660.6697        1660.9852        1511.4103        1635.0352
# 3        1678.9374        1626.8350        1516.5837        1665.8781
# 4        1678.6174        1640.9056        1513.5035        1653.2704
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1484.4518        1238.2606     3670.0451
# 1        1470.3009        1098.4788     3568.8258
# 2        1441.0173        1112.3632     3541.2620
# 3        1471.2127        1098.3154     3630.0822
# 4        1435.5180        1090.4059     3569.1653
#
# [5 rows x 31 columns]

# %%
df_train.tail()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 8755  20211231     19  33304.5400       569.3452         374.9229
# 8756  20211231     20  33368.7201       599.9827         395.0698
# 8757  20211231     21  34083.1721       630.5049         415.1424
# 8758  20211231     22  34380.0806       618.6265         407.3311
# 8759  20211231     23  37074.2785       734.2128         483.3418
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 8755         702.9942        1195.0912        1818.2627        1434.7351
# 8756         806.5718        1232.5401        1781.4567        1441.6411
# 8757         825.4794        1360.3197        1866.0852        1428.3237
# 8758         831.6651        1364.7723        1899.4216        1416.2191
# 8759         895.2420        1594.0355        2116.7695        1519.3632
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 8755        1439.8129  ...        1870.7877        1628.8025        1474.3560
# 8756        1469.7313  ...        1890.1752        1598.9256        1469.9603
# 8757        1490.6164  ...        1964.4149        1560.5875        1404.8125
# 8758        1473.4710  ...        2017.0313        1573.9912        1507.6313
# 8759        1552.7195  ...        2100.5122        1637.1683        1570.8625
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 8755        1136.8778        1399.4513        1262.9415        1342.7762
# 8756        1124.4243        1414.3330        1224.8609        1336.5298
# 8757        1174.9639        1477.2012        1250.2445        1336.1856
# 8758        1171.6865        1488.2721        1269.3231        1334.5079
# 8759        1251.8968        1514.6940        1379.1155        1319.0559
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 8755        1058.0542         749.3935     2239.1210
# 8756        1056.6818         756.4905     2226.3545
# 8757        1042.3110         750.1392     2249.0323
# 8758        1045.8411         762.5466     2263.6665
# 8759        1138.3249         816.1801     2520.7282
#
# [5 rows x 31 columns]

# %%
df_train.describe()
# Out:
#               기준일ID         시간대구분        총생활인구수  남자0세부터9세생활인구수  \
# count  4.351200e+04  43512.000000  43512.000000   43512.000000
# mean   2.019067e+07     11.500000  40764.541744     921.608027
# std    1.419499e+04      6.922266   3715.404186     152.320273
# min    2.017010e+07      0.000000  17151.568200     372.913900
# 25%    2.018033e+07      5.750000  37917.393025     814.411425
# 50%    2.019063e+07     11.500000  40169.603850     892.195000
# 75%    2.020100e+07     17.250000  43514.610950     999.298425
# max    2.021123e+07     23.000000  63617.153900    1601.056000
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean        606.575476       832.968472      2085.119648      2339.973284
# std         100.167872       132.507679       525.985477       427.471543
# min         245.747200       318.987800       890.752300      1101.848300
# 25%         536.081275       739.878475      1697.998250      1985.097425
# 50%         587.233150       826.975750      1941.925000      2285.892700
# 75%         657.665425       910.649025      2375.277975      2684.788400
# max        1053.389500      1430.056200      3808.746400      3557.036000
#
#        남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  \
# count     43512.000000     43512.000000  ...     43512.000000
# mean       1574.209999      1561.124021  ...      2218.213270
# std         192.182189       133.910584  ...       334.386737
# min         655.887700       654.076000  ...       866.126000
# 25%        1432.635050      1467.470500  ...      1974.532700
# 50%        1599.009750      1564.146050  ...      2222.348100
# 75%        1726.634800      1656.441550  ...      2469.915375
# max        2338.640300      2223.043600  ...      3469.687300
#
#        여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean       1733.594735      1680.890238      1480.537805      1595.243243
# std         197.192555       151.429376       111.521271       112.290665
# min         733.198500       601.527800       546.972000       566.203600
# 25%        1597.425275      1587.179200      1403.735950      1517.387375
# 50%        1741.221950      1678.785550      1474.317400      1590.972400
# 75%        1871.530450      1781.482600      1548.987000      1676.303925
# max        3021.380300      2446.386500      2676.118600      2378.446200
#
#        여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean       1399.003571      1449.522067      1272.040981       975.491433
# std          98.648202       122.337327       136.506027       119.220029
# min         452.171200       510.742700       486.130500       506.692200
# 25%        1332.561125      1361.725150      1169.623175       879.518100
# 50%        1395.628400      1432.954300      1278.173450       977.008800
# 75%        1463.688100      1523.645675      1368.214725      1065.705925
# max        2271.334700      2261.080200      2550.177900      1459.686400
#
#        여자70세이상생활인구수
# count  43512.000000
# mean    2934.793628
# std      385.223925
# min     1771.827900
# 25%     2609.950425
# 50%     2967.952950
# 75%     3244.784175
# max     5185.301900
#
# [8 rows x 31 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43512 entries, 0 to 8759
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  int64
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
#  16  남자70세이상생활인구수     43512 non-null  float64
#  17  여자0세부터9세생활인구수    43512 non-null  float64
#  18  여자10세부터14세생활인구수  43512 non-null  float64
#  19  여자15세부터19세생활인구수  43512 non-null  float64
#  20  여자20세부터24세생활인구수  43512 non-null  float64
#  21  여자25세부터29세생활인구수  43512 non-null  float64
#  22  여자30세부터34세생활인구수  43512 non-null  float64
#  23  여자35세부터39세생활인구수  43512 non-null  float64
#  24  여자40세부터44세생활인구수  43512 non-null  float64
#  25  여자45세부터49세생활인구수  43512 non-null  float64
#  26  여자50세부터54세생활인구수  43512 non-null  float64
#  27  여자55세부터59세생활인구수  43512 non-null  float64
#  28  여자60세부터64세생활인구수  43512 non-null  float64
#  29  여자65세부터69세생활인구수  43512 non-null  float64
#  30  여자70세이상생활인구수     43512 non-null  float64
# dtypes: float64(29), int64(2)
# memory usage: 10.6 MB

# %% [markdown]
# ---

# %% [markdown]
# # 3. 데이터 분석하기
# ## EDA for Feature Engineering
#
# * EDA는 명확한 목적하에, 반드시 workflow에 도움이 되는 결과를 도출해야 함.
# * EDA를 검색해봐도 좋음.
#
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제5] 데이터 형태 변경하기
# * df_total, df_test의 index를 리셋 하고, ['기준일ID']에 to_datetime 함수를 사용하여 데이터 형태를 변경하세요.

# %%
df_train['기준일ID'] = pd.to_datetime(df_train['기준일ID'], format='%Y%m%d')
df_train.reset_index(inplace=True)

# df_test.reset_index(inplace=True)
# df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'], format='%Y%m%d')

# %% [markdown]
# #### [실습문제6] 데이터 분포 알아보기
# * df_total 및 df_test의 '총생활인구수' 변수를 기준으로 각종 Chart를 그려보고 인사이트를 도출해보세요.

# %%
sns.lineplot(data=df_train, x='기준일ID', y='총생활인구수')
# Out:
# <AxesSubplot:xlabel='기준일ID', ylabel='총생활인구수'>
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54876 (\N{HANGUL SYLLABLE HWAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/user/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_train['year'] = df_train['기준일ID'].dt.year
df_train['month'] = df_train['기준일ID'].dt.month
df_train['day'] = df_train['기준일ID'].dt.day
df_train['weekday'] = df_train['기준일ID'].dt.dayofweek

# %%
ax = df_train.groupby('year')['총생활인구수'].mean().plot()
ax.set_xticks([2017,2018,2019,2020,2021])
plt.show()

# %%
ax = df_train.groupby('month')['총생활인구수'].mean().plot()
ax.set_xticks(range(1,13))
plt.show()

# %%
ax = df_train.groupby('weekday')['총생활인구수'].mean().plot()
plt.xticks(range(0,7), labels=['Mon','TUE', 'WED','THU', 'FRI', 'SAT', 'SUN'])
plt.show()

# %% [markdown]
# # 다중 공선성 체크

# %%
df_train.corr()
# Out:
#                     index         시간대구분    총생활인구수  남자0세부터9세생활인구수  \
# index            1.000000  2.753717e-03 -0.047869      -0.029759
# 시간대구분            0.002754  1.000000e+00 -0.500264       0.083468
# 총생활인구수          -0.047869 -5.002639e-01  1.000000       0.115086
# 남자0세부터9세생활인구수   -0.029759  8.346759e-02  0.115086       1.000000
# 남자10세부터14세생활인구수 -0.029759  8.346758e-02  0.115086       1.000000
# 남자15세부터19세생활인구수 -0.215864 -4.521216e-01  0.705389      -0.121825
# 남자20세부터24세생활인구수  0.027330 -5.050326e-01  0.896617       0.067329
# 남자25세부터29세생활인구수  0.024614 -5.813982e-01  0.883568      -0.226986
# 남자30세부터34세생활인구수  0.049497 -4.457942e-01  0.713386      -0.413976
# 남자35세부터39세생활인구수 -0.055540 -3.688774e-01  0.749021      -0.237445
# 남자40세부터44세생활인구수 -0.014035 -3.691275e-01  0.661081      -0.276294
# 남자45세부터49세생활인구수 -0.015871 -3.913907e-01  0.797955      -0.125470
# 남자50세부터54세생활인구수  0.014810 -3.440287e-01  0.581176      -0.135882
# 남자55세부터59세생활인구수 -0.164467 -3.070677e-01  0.768623       0.197322
# 남자60세부터64세생활인구수 -0.181038 -2.344568e-01  0.691445       0.230250
# 남자65세부터69세생활인구수 -0.172953 -2.584742e-01  0.738927       0.233466
# 남자70세이상생활인구수    -0.209283 -1.256615e-01  0.618990       0.291211
# 여자0세부터9세생활인구수    0.002538 -5.185806e-02  0.235583       0.800119
# 여자10세부터14세생활인구수  0.002538 -5.185804e-02  0.235583       0.800119
# 여자15세부터19세생활인구수 -0.094403 -4.974844e-01  0.766909      -0.153428
# 여자20세부터24세생활인구수  0.173786 -4.949388e-01  0.796976      -0.069743
# 여자25세부터29세생활인구수  0.075789 -4.794760e-01  0.747309      -0.344473
# 여자30세부터34세생활인구수 -0.016978 -4.100020e-01  0.783646      -0.252595
# 여자35세부터39세생활인구수  0.050815 -3.286512e-01  0.665822      -0.172494
# 여자40세부터44세생활인구수 -0.080287 -2.756570e-01  0.791599       0.268178
# 여자45세부터49세생활인구수 -0.070610 -3.327668e-01  0.758347       0.265957
# 여자50세부터54세생활인구수 -0.093061 -4.401617e-01  0.796340       0.083213
# 여자55세부터59세생활인구수 -0.170365 -2.882523e-01  0.730721       0.244841
# 여자60세부터64세생활인구수 -0.200283 -2.804259e-01  0.735106       0.328435
# 여자65세부터69세생활인구수 -0.233838 -1.823992e-01  0.625371       0.383480
# 여자70세이상생활인구수    -0.171825 -2.033846e-01  0.661370       0.399670
# year             0.000683 -4.082686e-15 -0.383021      -0.388380
# month            0.996233 -1.200105e-16 -0.043251      -0.030765
# day              0.090038 -3.473106e-17 -0.022385       0.022747
# weekday          0.001103 -8.006236e-18  0.026719      -0.290271
#
#                  남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# index                  -0.029759        -0.215864         0.027330
# 시간대구분                   0.083468        -0.452122        -0.505033
# 총생활인구수                  0.115086         0.705389         0.896617
# 남자0세부터9세생활인구수           1.000000        -0.121825         0.067329
# 남자10세부터14세생활인구수         1.000000        -0.121825         0.067329
# 남자15세부터19세생활인구수        -0.121825         1.000000         0.691657
# 남자20세부터24세생활인구수         0.067329         0.691657         1.000000
# 남자25세부터29세생활인구수        -0.226986         0.715979         0.851066
# 남자30세부터34세생활인구수        -0.413976         0.632364         0.614001
# 남자35세부터39세생활인구수        -0.237445         0.575146         0.559341
# 남자40세부터44세생활인구수        -0.276294         0.500706         0.443922
# 남자45세부터49세생활인구수        -0.125470         0.533338         0.634608
# 남자50세부터54세생활인구수        -0.135882         0.419844         0.363890
# 남자55세부터59세생활인구수         0.197322         0.462817         0.595068
# 남자60세부터64세생활인구수         0.230250         0.464556         0.587948
# 남자65세부터69세생활인구수         0.233466         0.474471         0.685477
# 남자70세이상생활인구수            0.291211         0.409302         0.623845
# 여자0세부터9세생활인구수           0.800119         0.074098         0.150795
# 여자10세부터14세생활인구수         0.800119         0.074098         0.150795
# 여자15세부터19세생활인구수        -0.153428         0.782746         0.705773
# 여자20세부터24세생활인구수        -0.069743         0.506219         0.755536
# 여자25세부터29세생활인구수        -0.344473         0.565212         0.620831
# 여자30세부터34세생활인구수        -0.252595         0.596598         0.615385
# 여자35세부터39세생활인구수        -0.172494         0.440172         0.428993
# 여자40세부터44세생활인구수         0.268178         0.532356         0.673505
# 여자45세부터49세생활인구수         0.265957         0.421611         0.527206
# 여자50세부터54세생활인구수         0.083213         0.588550         0.606765
# 여자55세부터59세생활인구수         0.244841         0.539075         0.643080
# 여자60세부터64세생활인구수         0.328435         0.393471         0.639751
# 여자65세부터69세생활인구수         0.383480         0.334161         0.562401
# 여자70세이상생활인구수            0.399670         0.326937         0.625454
# year                   -0.388380        -0.181401        -0.512966
# month                  -0.030765        -0.213407         0.033394
# day                     0.022747        -0.037220        -0.035051
# weekday                -0.290271         0.049566         0.008951
#
#                  남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  \
# index                   0.024614         0.049497        -0.055540  ...
# 시간대구분                  -0.581398        -0.445794        -0.368877  ...
# 총생활인구수                  0.883568         0.713386         0.749021  ...
# 남자0세부터9세생활인구수          -0.226986        -0.413976        -0.237445  ...
# 남자10세부터14세생활인구수        -0.226986        -0.413976        -0.237445  ...
# 남자15세부터19세생활인구수         0.715979         0.632364         0.575146  ...
# 남자20세부터24세생활인구수         0.851066         0.614001         0.559341  ...
# 남자25세부터29세생활인구수         1.000000         0.870475         0.759629  ...
# 남자30세부터34세생활인구수         0.870475         1.000000         0.791932  ...
# 남자35세부터39세생활인구수         0.759629         0.791932         1.000000  ...
# 남자40세부터44세생활인구수         0.716820         0.777719         0.792787  ...
# 남자45세부터49세생활인구수         0.747058         0.688111         0.735023  ...
# 남자50세부터54세생활인구수         0.546679         0.568109         0.665431  ...
# 남자55세부터59세생활인구수         0.563118         0.444949         0.560622  ...
# 남자60세부터64세생활인구수         0.479523         0.351987         0.463016  ...
# 남자65세부터69세생활인구수         0.535230         0.350518         0.424984  ...
# 남자70세이상생활인구수            0.378259         0.189551         0.278679  ...
# 여자0세부터9세생활인구수          -0.055539        -0.222951        -0.095940  ...
# 여자10세부터14세생활인구수        -0.055539        -0.222951        -0.095940  ...
# 여자15세부터19세생활인구수         0.779305         0.685765         0.637214  ...
# 여자20세부터24세생활인구수         0.805439         0.652120         0.610266  ...
# 여자25세부터29세생활인구수         0.869614         0.861776         0.776471  ...
# 여자30세부터34세생활인구수         0.824750         0.824075         0.833014  ...
# 여자35세부터39세생활인구수         0.680005         0.719593         0.765340  ...
# 여자40세부터44세생활인구수         0.587110         0.458330         0.579569  ...
# 여자45세부터49세생활인구수         0.560601         0.456480         0.571286  ...
# 여자50세부터54세생활인구수         0.678589         0.605854         0.667239  ...
# 여자55세부터59세생활인구수         0.527981         0.380743         0.480232  ...
# 여자60세부터64세생활인구수         0.480540         0.276887         0.391385  ...
# 여자65세부터69세생활인구수         0.336675         0.111669         0.289583  ...
# 여자70세이상생활인구수            0.374186         0.137787         0.264311  ...
# year                   -0.158806         0.058948         0.001414  ...
# month                   0.029451         0.052301        -0.052348  ...
# day                    -0.021081        -0.021307        -0.016981  ...
# weekday                 0.100302         0.226034         0.179542  ...
#
#                  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# index                  -0.070610        -0.093061        -0.170365
# 시간대구분                  -0.332767        -0.440162        -0.288252
# 총생활인구수                  0.758347         0.796340         0.730721
# 남자0세부터9세생활인구수           0.265957         0.083213         0.244841
# 남자10세부터14세생활인구수         0.265957         0.083213         0.244841
# 남자15세부터19세생활인구수         0.421611         0.588550         0.539075
# 남자20세부터24세생활인구수         0.527206         0.606765         0.643080
# 남자25세부터29세생활인구수         0.560601         0.678589         0.527981
# 남자30세부터34세생활인구수         0.456480         0.605854         0.380743
# 남자35세부터39세생활인구수         0.571286         0.667239         0.480232
# 남자40세부터44세생활인구수         0.560434         0.636882         0.333080
# 남자45세부터49세생활인구수         0.647739         0.637634         0.473965
# 남자50세부터54세생활인구수         0.532467         0.603294         0.399571
# 남자55세부터59세생활인구수         0.667101         0.664288         0.695117
# 남자60세부터64세생활인구수         0.489882         0.579616         0.778747
# 남자65세부터69세생활인구수         0.496435         0.578845         0.781405
# 남자70세이상생활인구수            0.366331         0.409062         0.750153
# 여자0세부터9세생활인구수           0.350736         0.254365         0.349255
# 여자10세부터14세생활인구수         0.350736         0.254365         0.349255
# 여자15세부터19세생활인구수         0.567424         0.612893         0.401002
# 여자20세부터24세생활인구수         0.631464         0.580465         0.294801
# 여자25세부터29세생활인구수         0.560170         0.625269         0.287906
# 여자30세부터34세생활인구수         0.608357         0.664474         0.385907
# 여자35세부터39세생활인구수         0.634782         0.632966         0.298164
# 여자40세부터44세생활인구수         0.617818         0.665999         0.711597
# 여자45세부터49세생활인구수         1.000000         0.685339         0.517783
# 여자50세부터54세생활인구수         0.685339         1.000000         0.658168
# 여자55세부터59세생활인구수         0.517783         0.658168         1.000000
# 여자60세부터64세생활인구수         0.596911         0.586184         0.735538
# 여자65세부터69세생활인구수         0.475454         0.459699         0.739215
# 여자70세이상생활인구수            0.471913         0.434083         0.715297
# year                   -0.131815        -0.122612        -0.581332
# month                  -0.067688        -0.089622        -0.170639
# day                    -0.007786        -0.022947        -0.002195
# weekday                -0.024308        -0.043581        -0.041798
#
#                  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수          year  \
# index                  -0.200283        -0.233838     -0.171825  6.834083e-04
# 시간대구분                  -0.280426        -0.182399     -0.203385 -4.082686e-15
# 총생활인구수                  0.735106         0.625371      0.661370 -3.830209e-01
# 남자0세부터9세생활인구수           0.328435         0.383480      0.399670 -3.883800e-01
# 남자10세부터14세생활인구수         0.328435         0.383480      0.399670 -3.883800e-01
# 남자15세부터19세생활인구수         0.393471         0.334161      0.326937 -1.814014e-01
# 남자20세부터24세생활인구수         0.639751         0.562401      0.625454 -5.129659e-01
# 남자25세부터29세생활인구수         0.480540         0.336675      0.374186 -1.588060e-01
# 남자30세부터34세생활인구수         0.276887         0.111669      0.137787  5.894752e-02
# 남자35세부터39세생활인구수         0.391385         0.289583      0.264311  1.413786e-03
# 남자40세부터44세생활인구수         0.250817         0.115297      0.090082  2.155130e-01
# 남자45세부터49세생활인구수         0.484979         0.394676      0.412506 -1.301174e-01
# 남자50세부터54세생활인구수         0.236558         0.209808      0.189498  1.274415e-01
# 남자55세부터59세생활인구수         0.744830         0.648814      0.673480 -4.074858e-01
# 남자60세부터64세생활인구수         0.744493         0.728443      0.730025 -6.023241e-01
# 남자65세부터69세생활인구수         0.814375         0.786256      0.809608 -6.828136e-01
# 남자70세이상생활인구수            0.797090         0.833563      0.869004 -8.678222e-01
# 여자0세부터9세생활인구수           0.332105         0.352808      0.353276 -2.932306e-01
# 여자10세부터14세생활인구수         0.332105         0.352808      0.353276 -2.932306e-01
# 여자15세부터19세생활인구수         0.400814         0.274726      0.285258 -3.564209e-02
# 여자20세부터24세생활인구수         0.382244         0.223760      0.273714  1.225248e-02
# 여자25세부터29세생활인구수         0.265295         0.082938      0.105222  2.001460e-01
# 여자30세부터34세생활인구수         0.337551         0.208448      0.207396  9.876977e-02
# 여자35세부터39세생활인구수         0.285964         0.114357      0.089673  2.302568e-01
# 여자40세부터44세생활인구수         0.637760         0.608865      0.616097 -4.414094e-01
# 여자45세부터49세생활인구수         0.596911         0.475454      0.471913 -1.318152e-01
# 여자50세부터54세생활인구수         0.586184         0.459699      0.434083 -1.226121e-01
# 여자55세부터59세생활인구수         0.735538         0.739215      0.715297 -5.813322e-01
# 여자60세부터64세생활인구수         1.000000         0.808191      0.831246 -6.563878e-01
# 여자65세부터69세생활인구수         0.808191         1.000000      0.860751 -7.481786e-01
# 여자70세이상생활인구수            0.831246         0.860751      1.000000 -8.109934e-01
# year                   -0.656388        -0.748179     -0.810993  1.000000e+00
# month                  -0.196372        -0.230949     -0.170258 -5.070805e-04
# day                    -0.015538        -0.017114     -0.012360  5.869648e-04
# weekday                -0.052949        -0.040656     -0.016267 -3.880134e-04
#
#                         month           day       weekday
# index            9.962326e-01  9.003805e-02  1.103382e-03
# 시간대구분           -1.200105e-16 -3.473106e-17 -8.006236e-18
# 총생활인구수          -4.325097e-02 -2.238507e-02  2.671928e-02
# 남자0세부터9세생활인구수   -3.076504e-02  2.274674e-02 -2.902710e-01
# 남자10세부터14세생활인구수 -3.076502e-02  2.274672e-02 -2.902710e-01
# 남자15세부터19세생활인구수 -2.134070e-01 -3.722008e-02  4.956586e-02
# 남자20세부터24세생활인구수  3.339361e-02 -3.505051e-02  8.950861e-03
# 남자25세부터29세생활인구수  2.945071e-02 -2.108098e-02  1.003023e-01
# 남자30세부터34세생활인구수  5.230147e-02 -2.130686e-02  2.260340e-01
# 남자35세부터39세생활인구수 -5.234777e-02 -1.698059e-02  1.795423e-01
# 남자40세부터44세생활인구수 -1.087820e-02 -1.983508e-02  1.349324e-01
# 남자45세부터49세생활인구수 -1.277418e-02 -1.244759e-02  1.498554e-01
# 남자50세부터54세생활인구수  1.427979e-02 -3.163823e-03  9.944678e-02
# 남자55세부터59세생활인구수 -1.631022e-01 -7.192463e-03  3.863232e-04
# 남자60세부터64세생활인구수 -1.792117e-01 -1.094185e-02  1.204213e-02
# 남자65세부터69세생활인구수 -1.707479e-01 -1.442165e-02 -2.200684e-02
# 남자70세이상생활인구수    -2.086105e-01 -1.122413e-02  1.969221e-02
# 여자0세부터9세생활인구수    2.284653e-03  3.459904e-03 -3.161517e-01
# 여자10세부터14세생활인구수  2.284660e-03  3.459899e-03 -3.161517e-01
# 여자15세부터19세생활인구수 -8.986498e-02 -3.148300e-02  9.189081e-02
# 여자20세부터24세생활인구수  1.814352e-01 -2.915416e-02  2.195094e-02
# 여자25세부터29세생활인구수  7.952343e-02 -7.982588e-03  1.239575e-01
# 여자30세부터34세생활인구수 -1.419458e-02 -1.186925e-02  1.420935e-01
# 여자35세부터39세생활인구수  5.398504e-02 -4.176741e-03  7.392559e-02
# 여자40세부터44세생활인구수 -7.756810e-02 -1.913425e-02 -8.730723e-03
# 여자45세부터49세생활인구수 -6.768790e-02 -7.785532e-03 -2.430847e-02
# 여자50세부터54세생활인구수 -8.962237e-02 -2.294703e-02 -4.358124e-02
# 여자55세부터59세생활인구수 -1.706394e-01 -2.195006e-03 -4.179771e-02
# 여자60세부터64세생활인구수 -1.963723e-01 -1.553781e-02 -5.294890e-02
# 여자65세부터69세생활인구수 -2.309492e-01 -1.711391e-02 -4.065569e-02
# 여자70세이상생활인구수    -1.702581e-01 -1.235951e-02 -1.626686e-02
# year            -5.070805e-04  5.869648e-04 -3.880134e-04
# month            1.000000e+00  6.501292e-03  1.158742e-03
# day              6.501292e-03  1.000000e+00 -2.613414e-03
# weekday          1.158742e-03 -2.613414e-03  1.000000e+00
#
# [35 rows x 35 columns]

# %%
x = ' + '.join(df_train.drop(['총생활인구수', '기준일ID', 'index', 'year', 'month', 'day', 'weekday'],axis=1).columns.to_list())

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor

model = ols(f'총생활인구수 ~ {x}',df_train)
res = model.fit(verbose=0)
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 총생활인구수   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.161e+15
# Date:                Fri, 21 Oct 2022   Prob (F-statistic):               0.00
# Time:                        10:53:25   Log-Likelihood:             2.1858e+05
# No. Observations:               43512   AIC:                        -4.371e+05
# Df Residuals:                   43482   BIC:                        -4.368e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.3361      0.020     16.731      0.000       0.297       0.375
# 시간대구분            3.362e-06   1.48e-06      2.271      0.023     4.6e-07    6.26e-06
# 남자0세부터9세생활인구수       1.1608      0.017     69.367      0.000       1.128       1.194
# 남자10세부터14세생활인구수     0.7554      0.025     29.686      0.000       0.706       0.805
# 남자15세부터19세생활인구수     1.0000   1.18e-07   8.47e+06      0.000       1.000       1.000
# 남자20세부터24세생활인구수     1.0000    5.9e-08   1.69e+07      0.000       1.000       1.000
# 남자25세부터29세생활인구수     1.0000   7.99e-08   1.25e+07      0.000       1.000       1.000
# 남자30세부터34세생활인구수     1.0000   1.16e-07   8.63e+06      0.000       1.000       1.000
# 남자35세부터39세생활인구수     1.0000   1.29e-07   7.76e+06      0.000       1.000       1.000
# 남자40세부터44세생활인구수     1.0000   1.39e-07   7.22e+06      0.000       1.000       1.000
# 남자45세부터49세생활인구수     1.0000   1.14e-07   8.77e+06      0.000       1.000       1.000
# 남자50세부터54세생활인구수     1.0000   1.25e-07      8e+06      0.000       1.000       1.000
# 남자55세부터59세생활인구수     1.0000   1.44e-07   6.94e+06      0.000       1.000       1.000
# 남자60세부터64세생활인구수     1.0000   1.68e-07   5.94e+06      0.000       1.000       1.000
# 남자65세부터69세생활인구수     1.0000   1.93e-07   5.18e+06      0.000       1.000       1.000
# 남자70세이상생활인구수        1.0000   7.75e-08   1.29e+07      0.000       1.000       1.000
# 여자0세부터9세생활인구수       1.2167      0.016     77.116      0.000       1.186       1.248
# 여자10세부터14세생활인구수     0.6430      0.026     24.739      0.000       0.592       0.694
# 여자15세부터19세생활인구수     1.0000   1.25e-07   8.01e+06      0.000       1.000       1.000
# 여자20세부터24세생활인구수     1.0000   5.15e-08   1.94e+07      0.000       1.000       1.000
# 여자25세부터29세생활인구수     1.0000   1.02e-07   9.85e+06      0.000       1.000       1.000
# 여자30세부터34세생활인구수     1.0000   1.18e-07   8.51e+06      0.000       1.000       1.000
# 여자35세부터39세생활인구수     1.0000   1.16e-07   8.63e+06      0.000       1.000       1.000
# 여자40세부터44세생활인구수     1.0000   1.34e-07   7.49e+06      0.000       1.000       1.000
# 여자45세부터49세생활인구수     1.0000   1.34e-07   7.45e+06      0.000       1.000       1.000
# 여자50세부터54세생활인구수     1.0000   1.52e-07   6.57e+06      0.000       1.000       1.000
# 여자55세부터59세생활인구수     1.0000   1.39e-07   7.21e+06      0.000       1.000       1.000
# 여자60세부터64세생활인구수     1.0000   1.37e-07   7.32e+06      0.000       1.000       1.000
# 여자65세부터69세생활인구수     1.0000    1.5e-07   6.65e+06      0.000       1.000       1.000
# 여자70세이상생활인구수        1.0000   5.43e-08   1.84e+07      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                    17846.734   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           805742.066
# Skew:                          -1.247   Prob(JB):                         0.00
# Kurtosis:                      23.933   Cond. No.                     3.97e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.97e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')
# Out:
#                  컬럼           VIF
# 0             시간대구분  1.800694e+00
# 1     남자0세부터9세생활인구수  1.113967e+11
# 2   남자10세부터14세생활인구수  1.113967e+11
# 3   남자15세부터19세생활인구수  4.197726e+00
# 4   남자20세부터24세생활인구수  1.652787e+01
# 5   남자25세부터29세생활인구수  2.002158e+01
# 6   남자30세부터34세생활인구수  8.501826e+00
# 7   남자35세부터39세생활인구수  5.102168e+00
# 8   남자40세부터44세생활인구수  4.989325e+00
# 9   남자45세부터49세생활인구수  4.251830e+00
# 10  남자50세부터54세생활인구수  2.715423e+00
# 11  남자55세부터59세생활인구수  3.576013e+00
# 12  남자60세부터64세생활인구수  3.765319e+00
# 13  남자65세부터69세생활인구수  5.168498e+00
# 14     남자70세이상생활인구수  8.974911e+00
# 15    여자0세부터9세생활인구수  9.291424e+10
# 16  여자10세부터14세생활인구수  9.291424e+10
# 17  여자15세부터19세생활인구수  4.948018e+00
# 18  여자20세부터24세생활인구수  1.339958e+01
# 19  여자25세부터29세생활인구수  1.975086e+01
# 20  여자30세부터34세생활인구수  9.208850e+00
# 21  여자35세부터39세생활인구수  5.278920e+00
# 22  여자40세부터44세생활인구수  3.800335e+00
# 23  여자45세부터49세생활인구수  3.898808e+00
# 24  여자50세부터54세생활인구수  3.862287e+00
# 25  여자55세부터59세생활인구수  4.929696e+00
# 26  여자60세부터64세생활인구수  5.955615e+00
# 27  여자65세부터69세생활인구수  5.510528e+00
# 28     여자70세이상생활인구수  7.491115e+00

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 20, 21년도의 생활총인구수는 감소한다 (코로나 때문으로 예상)
# 2. 월 데이터에서는 특별한 의미를 찾을 수 없었다
# 3. 요일별 데이터를 비교해보았을 때 주말의 생활 총 인구수가 더 적었다

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
# CSV로 저장
df_train.to_csv('df_train.csv', index=False)

# %% [markdown]
# # 4. (참고) 시계열 분석 기초 (Stationary / Normality)
#
# * 아래 주어진 코드를 기반으로 해당 데이터가 정상성과 정규성을 충족 하는지 확인해봅시다

# %% [markdown]
# #### [실습문제7] 정상성 분석
# * df_total['총생활인구수'] 데이터가 정상성을 띄는지 확인해보도록 하겠습니다
#
# * 정상성을 띈다 = 시계열 데이터의 평균과 분산이 일정하다.
#     - Dickey Fuller test 를 활용합니다
#     - Stationary (p-value < 0.05)
#
# ---
#
# * 귀무가설 : H0 : 시계열 데이터에 unit root를 포함한다 : nonstatinary / 정상 시계열이 아니다.
# * 대립가설 : H1 : 시계열 데이터에 unit root를 포함하지 않는다 : 정상 시계열이다.
# ---

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(y):
    dftest = adfuller(y, autolag='AIC')
    # autolag 'AIC' : 검정 AR 모형의 차수를 자동으로 결정
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)

# %%
adf_test(df_train['총생활인구수'])
# Out:
# test statistic         -8.447976e+00
# p-value                 1.692402e-13
# # of lags               5.500000e+01
# # of observations       4.345600e+04
# Critical Value (1%)    -3.430500e+00
# Critical Value (5%)    -2.861607e+00
# Critical Value (10%)   -2.566805e+00
# dtype: float64

# %%
# test statistic 검정 통계량 - 회귀 분석의 결과로 나타나는 계수
# p-value : p-value 추정치
# # of lags : 사용된 시차의 수(used lags)
# # of observations : 분석에 사용된 자료의 수

# critical values : 1%, 5%, 10%수준에 해당되는 검정 통계량의 값

# %% [markdown]
# #### [실습문제8] 정규성 분석
# * df_total['총생활인구수'] 데이터가 정규성을 띄는지 확인해보도록 하겠습니다
#
# * 정규성을 띈다 = 데이터의 분포가 정규분포를 이룬다.
#     * Shapiro test 를 활용합니다
#     * Normality (p-value > 0.05)
#
# ---
# * 귀무가설 : H0 : 시계열 데이터가 정규성을 충족한다.
# * 대립가설 : H1 : 시계열 데이터가 정규성을 충족하지 않는다.
# ---

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro_test = stats.shapiro(df_train['총생활인구수'])
shapiro_test
# Out:
# /home/user/.local/lib/python3.8/site-packages/scipy/stats/morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.9772825837135315, pvalue=0.0)

# %%
# shapiro test의 특징 : 데이터 수가 5000을 초과 하는 경우, 
#                      정규성 검정에 대한 p-value를 담보하지 못한다.(통계적 유의성이 떨어진다.)

# 시계열 데이터가 정규성을 충족하지 않습니다.

# %%
from scipy.stats import anderson
anderson(df_train['총생활인구수'])
# Out:
# AndersonResult(statistic=345.43763847483206, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
